# %%
#!wget https://raw.githubusercontent.com/vinid/data/master/dbpedia_sample_abstract_20k_unprep.txt

# %%
#!head -n 2 data/dbpedia_sample_abstract_20k_unprep.txt

# %%
import shutils

# %%
# !pip install configargparse

# %%
from appdirs import user_cache_dir
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-b2b28a32a2a1> in <module>
# ----> 1 from appdirs import user_cache_dir
#
# ModuleNotFoundError: No module named 'appdirs'

# %%
text_file = "data/dbpedia_sample_abstract_20k_unprep.txt"

# %%
import scipy 
from contextualized_topic_models.models.ctm import CombinedTM
from contextualized_topic_models.utils.data_preparation import TopicModelDataPreparation
from contextualized_topic_models.utils.preprocessing import WhiteSpacePreprocessing
import nltk
from sentence_transformers import SentenceTransformer
from contextualized_topic_models.datasets.dataset import CTMDataset

# %%
nltk.download('stopwords')

documents = [line.strip() for line in open(text_file, encoding="utf-8").readlines()[0:2000]]
sp = WhiteSpacePreprocessing(documents, stopwords_language='english')
preprocessed_documents, unpreprocessed_corpus, vocab = sp.preprocess()
# Out:
# [nltk_data] Downloading package stopwords to /home/rupak/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# /workspace/.conda/envs/cluster_ranking/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
ctm.get_topic_lists(10)[14]
# Out:
# ['born',
#  'january',
#  'player',
#  'politician',
#  'played',
#  'march',
#  'september',
#  'member',
#  'former',
#  'footballer']

# %%
unpreprocessed_corpus[1998]
# Out:
# 'Michał Tober (born April 10, 1975 in Warsaw) is a Polish politician. He was elected to Sejm on September 25, 2005 getting 8945 votes in 20 Warsaw district, candidating from Democratic Left Alliance list. He was also a member of Sejm 2001-2005.He used to serve as a spokesman of Leszek'

# %%
preprocessed_documents[:2], unpreprocessed_corpus[:2]
# Out:
# (['mid peninsula highway across peninsula canadian province ontario although highway connecting fort south decades international study published ministry',
#   'died march american photographer photography operated studio silver spring maryland later lived florida magazine photographer year'],
#  ['The Mid-Peninsula Highway is a proposed freeway across the Niagara Peninsula in the Canadian province of Ontario. Although plans for a highway connecting Hamilton to Fort Erie south of the Niagara Escarpment have surfaced for decades,it was not until The Niagara Frontier International Gateway Study was published by the Ministry',
#   "Monte Zucker (died March 15, 2007) was an American photographer. He specialized in wedding photography, entering it as a profession in 1947. In the 1970s he operated a studio in Silver Spring, Maryland. Later he lived in Florida. He was Brides Magazine's Wedding Photographer of the Year for 1990 and"])

# %%
len(unpreprocessed_corpus )
# Out:
# 2000

# %%
tp = TopicModelDataPreparation("paraphrase-distilroberta-base-v1")

training_dataset = tp.fit(text_for_contextual=unpreprocessed_corpus, text_for_bow=preprocessed_documents)
# Out:
# Batches:   0%|          | 0/10 [00:00<?, ?it/s]

# %%
from ipywidgets import FloatProgress

# %%
ctm = CombinedTM(bow_size=len(tp.vocab), contextual_size=768, n_components=20, num_epochs=10)
ctm.fit(training_dataset) # run the model
# Out:
# 0it [00:00, ?it/s]
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# ...

# %% [markdown]
# ## Look at topics found

# %%
topic_word_dist = ctm.get_topic_word_distribution()

# %%
vocab = [word for idx, word in ctm.train_data.idx2token.items()]

# %%
doc_topic_dist = ctm.get_doc_topic_distribution(training_dataset)
# Out:
# 0it [00:00, ?it/s]
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# ...

# %%
ctm.get_topic_lists(10)[1]
# Out:
# ['album',
#  'released',
#  'band',
#  'studio',
#  'music',
#  'singer',
#  'held',
#  'songwriter',
#  'uk',
#  'second']

# %%
ctm.get_word_distribution_by_topic_id(topic=1)
# Out:
# [('album', 0.0006325877),
#  ('released', 0.0006258571),
#  ('band', 0.00059873925),
#  ('studio', 0.00059634785),
#  ('music', 0.0005907091),
#  ('singer', 0.0005807977),
#  ('held', 0.00057075196),
#  ('songwriter', 0.00057011517),
#  ('uk', 0.0005697991),
#  ('second', 0.0005697385),
#  ('rock', 0.0005675116),
#  ('records', 0.0005661037),
#  ('united', 0.00056466035),
#  ('debut', 0.0005639223),
#  ('recorded', 0.0005635529),
#  ('songs', 0.00056320825),
#  ('guitarist', 0.0005631575),
#  ('albums', 0.000561784),
#  ('november', 0.00056075305),
#  ('first', 0.00055795733),
#  ('states', 0.000557836),
#  ('release', 0.00055572507),
#  ('gained', 0.00055510533),
#  ('producer', 0.0005548997),
#  ('democratic', 0.0005544315),
#  ('live', 0.0005535593),
#  ('indie', 0.00055290846),
#  ('award', 0.00055257505),
#  ('awards', 0.00055240304),
#  ('week', 0.0005521373),
#  ('recording', 0.00055136887),
#  ('fifth', 0.0005509922),
#  ('republican', 0.00055093656),
# ...

# %%
training_dataset.idx2token
# Out:
# {0: 'abbreviated',
#  1: 'abroad',
#  2: 'academic',
#  3: 'academy',
#  4: 'accepted',
#  5: 'access',
#  6: 'according',
#  7: 'accounting',
#  8: 'achieved',
#  9: 'acquired',
#  10: 'acres',
#  11: 'across',
#  12: 'act',
#  13: 'action',
#  14: 'actions',
#  15: 'active',
#  16: 'actor',
#  17: 'actress',
#  18: 'adapted',
#  19: 'addition',
#  20: 'adelaide',
#  21: 'adjacent',
#  22: 'administration',
#  23: 'administrative',
#  24: 'administrator',
#  25: 'adopted',
#  26: 'adult',
#  27: 'adults',
#  28: 'advance',
#  29: 'advanced',
#  30: 'affairs',
#  31: 'affiliate',
#  32: 'affiliated',
#  33: 'africa',
#  34: 'african',
#  35: 'age',
#  36: 'agencies',
#  37: 'agency',
#  38: 'agent',
#  39: 'ages',
#  40: 'air',
#  41: 'aired',
#  42: 'airline',
#  43: 'airport',
#  44: 'al',
#  45: 'alabama',
#  46: 'alaska',
#  47: 'albert',
#  48: 'alberta',
#  49: 'albion',
#  50: 'album',
#  51: 'albums',
#  52: 'alexander',
#  53: 'alfred',
#  54: 'allen',
#  55: 'allow',
# ...

# %%
training_dataset[0]['X_bow'].shape, training_dataset[0]['X_contextual'].shape
# Out:
# (torch.Size([1, 2000]), torch.Size([768]))

# %%
training_dataset[0].keys()
# Out:
# dict_keys(['X_bow', 'X_contextual'])

# %% [markdown]
# ## Train with our data format

# %%
import scipy 
from contextualized_topic_models.models.ctm import CombinedTM
from contextualized_topic_models.utils.data_preparation import TopicModelDataPreparation
from contextualized_topic_models.utils.preprocessing import WhiteSpacePreprocessing
import nltk
from sentence_transformers import SentenceTransformer
from contextualized_topic_models.datasets.dataset import CTMDataset

# %%
import scipy
from glob import glob 
inputs = glob("/workspace/topic-preprocessing/data/wikitext/processed/labeled/vocab_5k/*")

# %%
path = "/workspace/topic-preprocessing/data/wikitext/processed/labeled/vocab_5k/"

# %%
inputs
# Out:
# ['/workspace/topic-preprocessing/data/wikitext/processed/labeled/vocab_5k/logits',
#  '/workspace/topic-preprocessing/data/wikitext/processed/labeled/vocab_5k/train.embeds.npy',
#  '/workspace/topic-preprocessing/data/wikitext/processed/labeled/vocab_5k/scholar',
#  '/workspace/topic-preprocessing/data/wikitext/processed/labeled/vocab_5k/train.dtm.npz',
#  '/workspace/topic-preprocessing/data/wikitext/processed/labeled/vocab_5k/params.json',
#  '/workspace/topic-preprocessing/data/wikitext/processed/labeled/vocab_5k/test.metadata.jsonl',
#  '/workspace/topic-preprocessing/data/wikitext/processed/labeled/vocab_5k/train.metadata.jsonl',
#  '/workspace/topic-preprocessing/data/wikitext/processed/labeled/vocab_5k/vocab.json',
#  '/workspace/topic-preprocessing/data/wikitext/processed/labeled/vocab_5k/test.dtm.npz']

# %%
from pathlib import Path

# %%
import numpy as np

# %%
basepath = Path(path)
train_path = basepath / "train.dtm.npz"
vocab_path = basepath / "vocab.json"
dataset_path = basepath / "train.metadata.jsonl"
embeds_path = basepath / 'train.embeds.npy'

# %%
embeds_path
# Out:
# PosixPath('/workspace/topic-preprocessing/data/wikitext/processed/labeled/vocab_5k/train.embeds.npy')

# %%
train_path
# Out:
# PosixPath('/workspace/topic-preprocessing/data/wikitext/processed/labeled/vocab_5k/train.dtm.npz')

# %%
#import numpy as np 
a = scipy.sparse.load_npz(train_path)

# %%
from main import load_dataset, load_vocab, prepare_dataset

# %%
dataset = prepare_dataset(train_path=train_path,
                          vocab_path=vocab_path,
                          dataset_path=dataset_path,
                          embeds_path=embeds_path)
# Out:
# Shape of bow - (14290, 5000)
#
# Found Embedding File

# %%
dataset.X_bow.shape[1]
# Out:
# 5000

# %%
dataset.X_contextual.shape
# Out:
# (14290, 768)

# %%
ctm = CombinedTM(
            bow_size=dataset.X_bow.shape[1],
            contextual_size=768,
            n_components=50,
            num_epochs=100,
            )

# %%
# !main.py --input_dir /workspace/topic-preprocessing/data/wikitext/processed/labeled/vocab_5k/ --output_dir /workspace/rupak/.cache/test_ctm/ --num_topcis 50 --num_epochs 100
# Out:
# /bin/bash: main.py: command not found

# %%
ctm.fit(dataset)
# Out:
# Epoch: [100/100]	 Seen Samples: [1429000/1429000]	Train Loss: 6294.673360960462	Time: 0:00:07.942444: : 100it [13:19,  8.00s/it]
# Sampling: [20/20]: : 20it [00:45,  2.28s/it]

# %%
embeds_path.exists()
# Out:
# True

# %%
# !whoami
# Out:
# rupak

# %%
bow = scipy.sparse.load_npz(inputs[0])

# %%
import numpy as np 
import scipy

# %%
import json

# %%
unpreprocessed_corpus[:2]
# Out:
# ['The Mid-Peninsula Highway is a proposed freeway across the Niagara Peninsula in the Canadian province of Ontario. Although plans for a highway connecting Hamilton to Fort Erie south of the Niagara Escarpment have surfaced for decades,it was not until The Niagara Frontier International Gateway Study was published by the Ministry',
#  "Monte Zucker (died March 15, 2007) was an American photographer. He specialized in wedding photography, entering it as a profession in 1947. In the 1970s he operated a studio in Silver Spring, Maryland. Later he lived in Florida. He was Brides Magazine's Wedding Photographer of the Year for 1990 and"]

# %%
def load_dataset(dataset_path): 
    """
    Load dataset from jsonl for loading into the CTM
    """
    dataset = []
    with open(inputs[1]) as f: 
        for line in f: 
            doc = json.loads(line.rstrip("\n"))
            text = " ".join(doc["text"].split()[:600])  # after 512 will be truncated anyway
            dataset.append(text)

    return dataset

# %%
def load_vocab(vocab_path=inputs[-1]): 
    """
    Load the vocab json and return it in index2token format
    """
    
    with open(vocab_path) as f: 
        vocab = json.load(f)
    
    return {k:v for v, k in vocab.items()}

# %%
def prepare_dataset(model_path="paraphrase-distilroberta-base-v1", bow_path="/workspace/topic-preprocessing/data/wikitext/processed/full-vocab_5k/", batch_size=200):
    """
    Prepare the dataset for training ctm using their own dataset class
    Note: 
        1. The bow part of the model takes in data from our preprocessed input 
        2. The contextual part of the model simply runs sentence transformer on the documents
            (well, the first 512 tokens of it)
    
    """
    
    bow = scipy.sparse.load_npz(bow_path + "train.dtm.npz")
    vocab_path = bow_path + "vocab.json"
    print(f"Shape of bow - {bow.shape}\n")
    model = SentenceTransformer(model_path)
    texts = load_dataset(dataset_path=bow_path + "train.metadata.jsonl")
    embeddings = np.array(model.encode(texts, show_progress_bar=True, batch_size=batch_size))
    
    assert(bow.shape[0] == len(texts))
   
    idx2token = load_vocab(vocab_path )
    
    
    return CTMDataset(embeddings, bow, idx2token)

# %%
prepared_dataset = prepare_dataset()
# Out:
# Shape of bow - (28472, 5000)
# Batches:   0%|          | 0/143 [00:00<?, ?it/s]

# %%
ctm = CombinedTM(bow_size=len(ctm_vocab), contextual_size=768, n_components=50, num_epochs=100)
ctm.fit(prepared_dataset) # run the model
# Out:
# 0it [00:00, ?it/s]
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# ...

# %%
ctm.get_topic_lists(10)[1]
# Out:
# ['song',
#  'video',
#  'beyoncé',
#  'gaga',
#  'madonna',
#  'number',
#  'performance',
#  'spears',
#  'rihanna',
#  'dance']

# %%
ctm.save(models_dir="models/")
# Out:
# /workspace/.conda/envs/cluster_ranking/lib/python3.9/site-packages/contextualized_topic_models/models/ctm.py:413: Warning: This is an experimental feature that we has not been fully tested. Refer to the following issue:https://github.com/MilaNLProc/contextualized-topic-models/issues/38
#   warnings.warn("This is an experimental feature that we has not been fully tested. Refer to the following issue:"

# %%
ct = CombinedTM(bow_size=5000, contextual_size=768)
ct.load("models/contextualized_topic_model_nc_50_tpm_0.0_tpv_0.98_hs_prodLDA_ac_(100, 100)_do_softplus_lr_0.2_mo_0.002_rp_0.99/", epoch=99)
# Out:
# /workspace/.conda/envs/cluster_ranking/lib/python3.9/site-packages/contextualized_topic_models/models/ctm.py:438: Warning: This is an experimental feature that we has not been fully tested. Refer to the following issue:https://github.com/MilaNLProc/contextualized-topic-models/issues/38
#   warnings.warn("This is an experimental feature that we has not been fully tested. Refer to the following issue:"

# %%
ct.get_topic_lists(10)[1]
# Out:
# ['song',
#  'video',
#  'beyoncé',
#  'gaga',
#  'madonna',
#  'number',
#  'performance',
#  'spears',
#  'rihanna',
#  'dance']

# %% [markdown]
# ## Look at outputs

# %%
topic_word_dist = ctm.get_topic_word_distribution()

# %%
doc_topic_dist = ctm.get_doc_topic_distribution(dataset)
# Out:
# Sampling: [20/20]: : 20it [00:46,  2.32s/it]

# %%
topic_word_dist.shape, type(topic_word_dist)
# Out:
# ((50, 5000), numpy.ndarray)

# %%
doc_topic_dist.shape, type(doc_topic_dist)
# Out:
# ((14290, 50), numpy.ndarray)

# %%
topic_word_dist.shape
# Out:
# (50, 5000)
